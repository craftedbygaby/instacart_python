# %% [markdown]
# # TABLE OF CONTENTS
# ### 01. Importing Libraries
# ### 02. Importing data
# ### 03. Merging of the dataframes

# %% [markdown]
# # 01. Importing Libraries

# %%
# Import Libraries
import pandas as pd
import numpy as np
import os

# %% [markdown]
# # 02. Importing data

# %%
path = r'C:\Users\gabri\OneDrive\Desktop\CF Data Analysys Course\Data Analytics Immersion\A4 Achivement\Instacart Basket Analysis'

# %%
# ords_prior dataframe
df_ords_prior = pd.read_csv(os.path.join(path, '02 Data', 'Original Data', 'orders_products_prior.csv'), index_col = False)

# %%
# orders dataframe
df_ords = pd.read_csv(os.path.join(path, '02 Data', 'Prepared Data', 'orders_checked.csv'),  index_col = False)

# %%
# dataframes in this notebook
    # df_ords - most up to date after consitency check
    # df_ords_prior 
    # df_merged_large = inner merge of df_ords_prior and df_ords

# %%
df_ords_prior.head()
# Out:
#    order_id  product_id  add_to_cart_order  reordered
# 0         2       33120                  1          1
# 1         2       28985                  2          1
# 2         2        9327                  3          0
# 3         2       45918                  4          1
# 4         2       30035                  5          0

# %%
df_ords.head()
# Out:
#    Unnamed: 0  order_id  user_id  order_sequence_per_user  orders_day_of_week  \
# 0           0   2539329        1                        1                   2
# 1           1   2398795        1                        2                   3
# 2           2    473747        1                        3                   3
# 3           3   2254736        1                        4                   4
# 4           4    431534        1                        5                   4
#
#    order_hour_of_day  days_since_prior_order  new_customer
# 0                  8                     NaN          True
# 1                  7                    15.0         False
# 2                 12                    21.0         False
# 3                  7                    29.0         False
# 4                 15                    28.0         False

# %%
# dropping unnecessary columns before exporting - Unnamed
df_ords_clean = df_ords.drop(columns = 'Unnamed: 0')

# %%
df_ords_clean
# Out:
#          order_id  user_id  order_sequence_per_user  orders_day_of_week  \
# 0         2539329        1                        1                   2
# 1         2398795        1                        2                   3
# 2          473747        1                        3                   3
# 3         2254736        1                        4                   4
# 4          431534        1                        5                   4
# ...           ...      ...                      ...                 ...
# 3421078   2266710   206209                       10                   5
# 3421079   1854736   206209                       11                   4
# 3421080    626363   206209                       12                   1
# 3421081   2977660   206209                       13                   1
# 3421082    272231   206209                       14                   6
#
#          order_hour_of_day  days_since_prior_order  new_customer
# ...

# %%
df_ords = df_ords_clean

# %%
df_ords
# Out:
#          order_id  user_id  order_sequence_per_user  orders_day_of_week  \
# 0         2539329        1                        1                   2
# 1         2398795        1                        2                   3
# 2          473747        1                        3                   3
# 3         2254736        1                        4                   4
# 4          431534        1                        5                   4
# ...           ...      ...                      ...                 ...
# 3421078   2266710   206209                       10                   5
# 3421079   1854736   206209                       11                   4
# 3421080    626363   206209                       12                   1
# 3421081   2977660   206209                       13                   1
# 3421082    272231   206209                       14                   6
#
#          order_hour_of_day  days_since_prior_order  new_customer
# ...

# %%
df_ords.shape
# Out:
# (3421083, 7)

# %%
df_ords_prior.shape
# Out:
# (32434489, 4)

# %% [markdown]
# # 03. Merging of the dataframes

# %%
# merge of 2 data sets
df_merged_large = df_ords.merge(df_ords_prior, on = 'order_id', indicator = True)

# %%
df_merged_large.head()
# Out:
#    order_id  user_id  order_sequence_per_user  orders_day_of_week  \
# 0   2539329        1                        1                   2
# 1   2539329        1                        1                   2
# 2   2539329        1                        1                   2
# 3   2539329        1                        1                   2
# 4   2539329        1                        1                   2
#
#    order_hour_of_day  days_since_prior_order  new_customer  product_id  \
# 0                  8                     NaN          True         196
# 1                  8                     NaN          True       14084
# 2                  8                     NaN          True       12427
# 3                  8                     NaN          True       26088
# 4                  8                     NaN          True       26405
#
#    add_to_cart_order  reordered _merge
# 0                  1          0   both
# 1                  2          0   both
# ...

# %%
df_merged_large['_merge'].value_counts()
# Out:
# _merge
# both          32434489
# left_only            0
# right_only           0
# Name: count, dtype: int64

# %%
# export prepared dataset
df_merged_large.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'orders_products_combined.pkl'))

# %%
df_merged_large.shape
# Out:
# (32434489, 11)

# %%
df_ords_prior.head()
# Out:
#    order_id  product_id  add_to_cart_order  reordered
# 0         2       33120                  1          1
# 1         2       28985                  2          1
# 2         2        9327                  3          0
# 3         2       45918                  4          1
# 4         2       30035                  5          0

# %%
df_ords_prior.isnull().sum()
# Out:
# order_id             0
# product_id           0
# add_to_cart_order    0
# reordered            0
# dtype: int64

# %%
df_ords_prior = df_ords_prior[df_ords_prior.duplicated()]

# %%
df_ords_prior.head()
# Out:
# Empty DataFrame
# Columns: [order_id, product_id, add_to_cart_order, reordered]
# Index: []
