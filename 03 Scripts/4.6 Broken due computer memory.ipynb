# %% [markdown]
# # 01. Importing Libraries

# %%
# Import Libraries
import pandas as pd
import numpy as np
import os

# %% [markdown]
# # 02. Importing data

# %%
path = r'C:\Users\gabri\OneDrive\Desktop\CF Data Analysys Course\Data Analytics Immersion\A4 Achivement\Instacart Basket Analysis'

# %%
# merged dataframe
df_ords_prods = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_combined.pkl'))

# %%
# products dataframe
dfprods = pd.read_csv(os.path.join(path, '02 Data', 'Prepared Data', 'products_checked.csv'), index_col = False)

# %%
# Dataframes in this notebook
    # df_ords_prods - inner merge of df_ords_prior and df_ords
    # df_prods
# export prepared dataset
# df_merged_large.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'orders_products_combined.pkl'))

# %%
df_ords_prods.shape
# Out:
# (32434489, 11)

# %%
df_prods = dfprods

# %%
df_prods.shape
# Out:
# (49672, 6)

# %%
df_ords_prods.head()
# Out:
#    order_id  user_id  order_sequence_per_user  orders_day_of_week  \
# 0   2539329        1                        1                   2
# 1   2539329        1                        1                   2
# 2   2539329        1                        1                   2
# 3   2539329        1                        1                   2
# 4   2539329        1                        1                   2
#
#    order_hour_of_day  days_since_prior_order  new_customer  product_id  \
# 0                  8                     NaN          True         196
# 1                  8                     NaN          True       14084
# 2                  8                     NaN          True       12427
# 3                  8                     NaN          True       26088
# 4                  8                     NaN          True       26405
#
#    add_to_cart_order  reordered _merge
# 0                  1          0   both
# 1                  2          0   both
# ...

# %%
df_prods.head()
# Out:
#    Unnamed: 0  product_id                                       product_name  \
# 0           0           1                         Chocolate Sandwich Cookies
# 1           1           2                                   All-Seasons Salt
# 2           2           3               Robust Golden Unsweetened Oolong Tea
# 3           3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...
# 4           4           5                          Green Chile Anytime Sauce
#
#    aisle_id  department_id  prices
# 0        61             19     5.8
# 1       104             13     9.3
# 2        94              7     4.5
# 3        38              1    10.5
# 4         5             13     4.3

# %%
# dropping unnecessary columns before merging - Unnamed
df_prods = df_prods.drop(columns = 'Unnamed: 0')

# %%
df_prods.head()
# Out:
#    product_id                                       product_name  aisle_id  \
# 0           1                         Chocolate Sandwich Cookies        61
# 1           2                                   All-Seasons Salt       104
# 2           3               Robust Golden Unsweetened Oolong Tea        94
# 3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4           5                          Green Chile Anytime Sauce         5
#
#    department_id  prices
# 0             19     5.8
# 1             13     9.3
# 2              7     4.5
# 3              1    10.5
# 4             13     4.3

# %%
df_prods.shape
# Out:
# (49672, 5)

# %% [markdown]
# #### Step 5 - Most suitable way to merge the dataframes here is via product_id column. The column has almost the same count on unique values, so inner join would not generate a data loss issue

# %%
df_ords_prods['product_id'].nunique()
# Out:
# 49677

# %%
df_prods['product_id'].nunique()
# Out:
# 49670

# %%
# dropping _merge columns to aovid error
df_ords_prods = df_ords_prods.drop(columns = '_merge')

# %%
df_ords_prods.head()
# Out:
#    order_id  user_id  order_sequence_per_user  orders_day_of_week  \
# 0   2539329        1                        1                   2
# 1   2539329        1                        1                   2
# 2   2539329        1                        1                   2
# 3   2539329        1                        1                   2
# 4   2539329        1                        1                   2
#
#    order_hour_of_day  days_since_prior_order  new_customer  product_id  \
# 0                  8                     NaN          True         196
# 1                  8                     NaN          True       14084
# 2                  8                     NaN          True       12427
# 3                  8                     NaN          True       26088
# 4                  8                     NaN          True       26405
#
#    add_to_cart_order  reordered
# 0                  1          0
# 1                  2          0
# 2                  3          0
# ...

# %%
# merge without overwriting to check the code
pd.merge(df_ords_prods,df_prods, on = 'product_id', indicator = True)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[29], line 2
#       1 # merge without overwriting to check the code
# ----> 2 pd.merge(df_ords_prods,df_prods, on = 'product_id', indicator = True)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\reshape\merge.py:184, in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     169 else:
#     170     op = _MergeOperation(
#     171         left_df,
#     172         right_df,
#    (...)    182         validate=validate,
#     183     )
# --> 184     return op.get_result(copy=copy)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\reshape\merge.py:888, in _MergeOperation.get_result(self, copy)
#     884     self.left, self.right = self._indicator_pre_merge(self.left, self.right)
#     886 join_index, left_indexer, right_indexer = self._get_join_info()
# ...
