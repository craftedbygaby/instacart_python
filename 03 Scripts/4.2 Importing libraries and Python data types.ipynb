# %% [markdown]
# # TABLE OF CONTENTS
# ### 01. Importing Libraries
# ### 02. Data Types

# %% [markdown]
# # 01. Importing Libraries

# %%
# Import Libraries
import pandas as pd
import numpy as np
import os

# %% [markdown]
# # 02. Data Types

# %%
x = 2

# %%
x
# Out:
# 2

# %%
print(x)
# Out:
# 2

# %%
type(x)
# Out:
# int

# %%
y = 5.678

# %%
type(y)
# Out:
# float

# %%
z = 'Brazil'

# %%
type(z)
# Out:
# str

# %%
type(True)
# Out:
# bool

# %%
type(False)
# Out:
# bool

# %%
print(x)
# Out:
# 2

# %%
x + 4
# Out:
# 6

# %%
x = x + 4

# %%
print(x)
# Out:
# 6

# %%
'Hello, ' + 'Marley'
# Out:
# 'Hello, Marley'

# %%
'potato' * 2
# Out:
# 'potatopotato'

# %%
x == y
# Out:
# False

# %%
type(x == y)
# Out:
# bool

# %%
99 + 1
# Out:
# 100

# %%
50 + 50
# Out:
# 100

# %%
120 - 20
# Out:
# 100

# %%
a = 1.5

# %%
b = 1.5

# %%
a / b
# Out:
# 1.0

# %%
1.5 / 1.5
# Out:
# 1.0

# %%
s = 'sun'

# %%
F = 'flower'

# %%
s + F
# Out:
# 'sunflower'

# %%
c = 'Kitties are '

# %%
d = 'cute. '

# %%
e = 'funny. '

# %%
f = 'not like dogs.'

# %%
c + f
# Out:
# 'Kitties are not like dogs.'

# %%
g = c + d

# %%
print(g)
# Out:
# Kitties are cute.

# %%
g * 100
# Out:
# 'Kitties are cute. Kitties are cute. Kitties are cute. Kitties are cute. Kitties are cute. Kitties are cute. Kitties are cute. Kitties are cute. Kitties are cute. Kitties are cute. Kitties are cute. Kitties are cute. Kitties are cute. Kitties are cute. Kitties are cute. Kitties are cute. Kitties are cute. Kitties are cute. Kitties are cute. Kitties are cute. Kitties are cute. Kitties are cute. Kitties are cute. Kitties are cute. Kitties are cute. Kitties are cute. Kitties are cute. Kitties are cute. Kitties are cute. Kitties are cute. Kitties are cute. Kitties are cute. Kitties are cute. Kitties are cute. Kitties are cute. Kitties are cute. Kitties are cute. Kitties are cute. Kitties are cute. Kitties are cute. Kitties are cute. Kitties are cute. Kitties are cute. Kitties are cute. Kitties are cute. Kitties are cute. Kitties are cute. Kitties are cute. Kitties are cute. Kitties are cute. Kitties are cute. Kitties are cute. Kitties are cute. Kitties are cute. Kitties are cute. Kitties
# ...
